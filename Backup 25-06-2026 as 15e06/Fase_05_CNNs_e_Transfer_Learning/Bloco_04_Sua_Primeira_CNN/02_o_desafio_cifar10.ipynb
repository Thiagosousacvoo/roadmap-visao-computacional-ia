# %% [markdown]
# <div style="background: linear-gradient(135deg, #7209b7 0%, #560bad 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🐸 02 — O Temido CIFAR-10</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 05 · Bloco 04 · CNN Real</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Números são fáceis. O CIFAR-10 traz sapos, aviões, cavalos e caminhões em 3 canais de cor RGB super borrados (32x32).
# Aqui a CNN vai suar para conseguir passar dos 80% de precisão.
#
# ---

# %% [markdown]
# ## A Metodologia
# Para esse desafio, a sua rede precisará ser significativamente mais profunda. O MNIST precisou de 2 convoluções. O CIFAR pedirá de 3 a 5 Convoluções com dezenas de `out_channels` em cada uma.
