# %% [markdown]
# <div style="background: linear-gradient(135deg, #f72585 0%, #b5179e 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">👀 01 — O que a Máquina Vê?</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 05 · Bloco 02 · Feature Maps</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Quando colocamos `out_channels=32`, a Rede Neural cospe 32 Imagens Pretas e Brancas.
# Cada imagem foca em algo. Uma foca em "bordas horizontais", a outra foca em "texturas peludas", a outra em "pontos luminosos". Esses são os **Feature Maps**.
#
# ---

# %%
import torch.nn as nn
print("Neste notebook nós usamos um Recurso Avançado chamado Forward Hooks do PyTorch. Ele permite 'grampear' a saída de uma camada no meio do processamento e visualizar o que o filtro de fato enxergou na imagem real.")
