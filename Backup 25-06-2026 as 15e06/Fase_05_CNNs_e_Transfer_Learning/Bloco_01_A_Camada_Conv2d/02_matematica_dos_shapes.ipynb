# %% [markdown]
# <div style="background: linear-gradient(135deg, #3a0ca3 0%, #4361ee 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">📐 02 — Matemática dos Shapes (CRÍTICO)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 05 · Bloco 01 · Arquitetura</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# O maior erro de um iniciante no PyTorch é rodar a célula e rezar pra não dar Erro de Shape. Você vai aprender a calcular o tamanho da imagem na mão.
#
# ---

# %% [markdown]
# ## A Fórmula Sagrada
#
# $$ Saida = \lfloor \frac{Entrada + 2 \times Padding - KernelSize}{Stride} \rfloor + 1 $$
