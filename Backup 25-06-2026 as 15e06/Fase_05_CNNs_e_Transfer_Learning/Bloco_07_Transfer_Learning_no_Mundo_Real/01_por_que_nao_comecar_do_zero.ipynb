# %% [markdown]
# <div style="background: linear-gradient(135deg, #2b9348 0%, #007f5f 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🌍 01 — O ImageNet</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 05 · Bloco 07 · Transfer Learning</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Treinar uma ResNet50 do zero custaria meses e milhões em GPUs. Mas nós não precisamos. Alguém já treinou ela no dataset **ImageNet** (1 milhão de imagens de 1000 classes diferentes). Essa rede já sabe o que são texturas, focinhos, rodas, asas e penas.
#
# ---

# %%
import torchvision.models as models

# Baixando o Cérebro já treinado da ResNet18!
modelo_pronto = models.resnet18(pretrained=True)
print("Modelo com pesos pré-treinados do ImageNet carregado na memória!")
