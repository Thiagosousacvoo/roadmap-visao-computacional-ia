# %% [markdown]
# <div style="background: linear-gradient(135deg, #023e8a 0%, #0096c7 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">☁️ 02 — Nuvem de Pontos com Open3D</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 11 · Bloco 02 · Nuvem de Pontos</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Se você juntar a Imagem (RGB) com a Profundidade (Depth) em uma matriz Intrínseca `K`, você consegue jogar todos os pixels da tela no espaço formando uma Point Cloud densa.
#
# ---

# %% [markdown]
# Neste caderno, nós usaremos o ecossistema `open3d` para desenhar visualizadores nativos na janela de Python, permitindo que você navegue e gire a foto em 3D usando o mouse.
