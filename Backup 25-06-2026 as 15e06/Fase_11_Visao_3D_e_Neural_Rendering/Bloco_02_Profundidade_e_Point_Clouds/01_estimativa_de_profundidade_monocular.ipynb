# %% [markdown]
# <div style="background: linear-gradient(135deg, #023e8a 0%, #0096c7 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🕳️ 01 — DepthAnything (Fingindo Ter Dois Olhos)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 11 · Bloco 02 · Nuvem de Pontos</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Você tem apenas um olho (uma câmera) na testa. Se você ver uma foto no Instagram, como você sabe a distância dos objetos? A IA faz a mesma coisa: ela adivinha pelo contexto (Modelos de Estimativa de Profundidade).
#
# ---

# %%
print("Usando o pipeline do HuggingFace:")
print("from transformers import pipeline")
print("depth_estimator = pipeline('depth-estimation', model='depth-anything/Depth-Anything-V2-Small')")
print("\nEsse modelo olhará para qualquer JPG plano e cuspirá uma imagem com mapa de calor das distâncias! O primeiro passo para o 3D.")
