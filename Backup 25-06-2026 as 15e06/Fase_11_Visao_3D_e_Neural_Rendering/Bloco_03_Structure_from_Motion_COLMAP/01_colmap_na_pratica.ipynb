# %% [markdown]
# <div style="background: linear-gradient(135deg, #ff5400 0%, #ff0054 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">📷 01 — Onde as Câmeras Estavam? (SfM)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 11 · Bloco 03 · Fotogrametria</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Nenhuma IA consegue desenhar o ambiente 3D do seu quarto se ela não souber EXATAMENTE onde a câmera do seu celular estava a cada segundo do vídeo. Vamos usar o padrão de Hollywood para extrair essas poses: o **COLMAP**.
#
# ---

# %%
print("Pipeline do Structure from Motion (SfM):")
print("1. O COLMAP acha quinas na foto (SIFT).")
print("2. Ele liga a quina da Foto A com a quina da Foto B (Feature Matching).")
print("3. Ele triangula o cruzamento dos raios e cospe as Poses da Câmera [R|t].")
