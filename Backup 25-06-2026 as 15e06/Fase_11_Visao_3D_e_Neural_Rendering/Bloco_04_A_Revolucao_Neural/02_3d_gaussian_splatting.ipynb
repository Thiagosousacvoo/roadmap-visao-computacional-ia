# %% [markdown]
# <div style="background: linear-gradient(135deg, #7209b7 0%, #3a0ca3 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">💥 02 — O Assassino do NeRF (Gaussian Splatting)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 11 · Bloco 04 · Rendering</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# O NeRF demora 30 minutos para renderizar um Frame porque precisa atirar raios para todo lado. O Gaussian Splatting (2023) faz isso a 150 Frames por Segundo.
#
# ---

# %%
print("A sacada:")
print("Em vez de atirar raios invisíveis, a IA joga milhões de Bolinhas Mágicas (Gaussianas 3D) pelo espaço.")
print("Essas bolinhas têm Eixo Maior, Eixo Menor, Cor (Harmônicos Esféricos) e Opacidade.")
print("Sua Placa de Vídeo sabe pintar essas bolinhas instantaneamente! (Rasterização)")
