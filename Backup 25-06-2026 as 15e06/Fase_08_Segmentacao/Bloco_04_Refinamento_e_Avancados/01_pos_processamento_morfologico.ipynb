# %% [markdown]
# <div style="background: linear-gradient(135deg, #a8dadc 0%, #457b9d 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🧹 01 — Limpando a Sujeira (Morfologia)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 08 · Bloco 04 · Refinamento</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# A IA nunca gera máscaras perfeitas. Às vezes ficam "buracos" no meio do pulmão, ou ruídos finos fora do pulmão. Nós limpamos isso com Morfologia Matemática clássica.
#
# ---

# %%
import cv2
import numpy as np

# Suponha que "mascara" é a predição cheia de ruídos.
print("Dica Prática: MORPH_OPEN remove poeira de fora.")
print("MORPH_CLOSE tampa os buracos de dentro.")
print("Sempre rode um CLOSING depois que a rede prever!")
