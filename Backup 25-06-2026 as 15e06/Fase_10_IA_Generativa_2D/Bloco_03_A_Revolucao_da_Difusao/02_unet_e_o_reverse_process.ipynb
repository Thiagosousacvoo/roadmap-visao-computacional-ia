# %% [markdown]
# <div style="background: linear-gradient(135deg, #ff006e 0%, #8338ec 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🛠️ 02 — Reverse Process (Adivinhando Ruído)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 10 · Bloco 03 · Difusão</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Aqui está o segredo que vale bilhões de dólares. A U-Net do Stable Diffusion não tenta adivinhar o Cachorro original. Ela pega a imagem suja no passo t=500 e a única coisa que ela adivinha é: **"Qual foi o ruído exato adicionado entre o passo 499 e o 500?"**
#
# Se você consegue adivinhar o ruído, você pode subtrair ele. Se você subtrair ele 1000 vezes... você gera o Cachorro do nada.

# %%
print("A Loss é maravilhosamente simples:")
print("loss = MSE( ruido_real, U_Net(imagem_suja, passo_T) )")
