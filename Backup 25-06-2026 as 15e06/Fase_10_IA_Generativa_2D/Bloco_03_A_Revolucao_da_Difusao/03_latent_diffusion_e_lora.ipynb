# %% [markdown]
# <div style="background: linear-gradient(135deg, #ff006e 0%, #8338ec 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🧠 03 — Latent Diffusion e LoRA</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 10 · Bloco 03 · Difusão</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Rodar 1000 passos na resolução 512x512 requer Data Centers gigantes. A solução (Stable Diffusion)? Use o VAE do Bloco 01 para esmagar a imagem para 64x64. Depois, faça todo o processo de Ruído nesse quadrado minúsculo. Depois Descomprima!
#
# ---

# %% [markdown]
# ## Fine-Tuning com LoRA
# Em vez de atualizar 1 bilhão de pesos para ensinar o Rosto do seu cachorro, nós adicionamos uma matriz microscópica (Low-Rank Adaptation) grudada na rede. Isso permite treinar modelos colossais no seu próprio notebook!
