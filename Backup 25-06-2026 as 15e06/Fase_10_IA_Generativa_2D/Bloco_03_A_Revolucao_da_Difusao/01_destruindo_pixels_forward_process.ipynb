# %% [markdown]
# <div style="background: linear-gradient(135deg, #ff006e 0%, #8338ec 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🌪️ 01 — Forward Process (Destruição)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 10 · Bloco 03 · Difusão</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Nós vamos pegar a foto de um cachorro e vamos adicionar Ruído Gaussiano passo a passo por 1000 vezes, até ela virar TV fora do ar. Por que? Para ensinar a IA como a sujeira se acumula.
#
# ---

# %%
import torch

print("Cronograma de Ruído (Beta Schedule):")
print("Começamos colocando bem pouco ruído (ex: 0.0001).")
print("No passo 1000, colocamos bastante ruído (ex: 0.02).")
print("A física da difusão de termodinâmica prova que no passo T, a imagem original x0 foi inteiramente apagada.")
