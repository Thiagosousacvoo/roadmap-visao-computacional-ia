# %% [markdown]
# <div style="background: linear-gradient(135deg, #3a0ca3 0%, #4361ee 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">➕ 01 — Matemática de Atributos Visuais</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 10 · Bloco 04 · Latentes</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Se o espaço latente for bem treinado (com a Loss de Kullback-Leibler que estudamos), ele vira um espaço matemático. A direção "Norte" pode significar "Adicionar Óculos". A direção "Leste" pode significar "Sorriso".
#
# ---

# %%
print("Aritmética do Word2Vec aplicada a Imagens:\n")
print("Vetor(Rei) - Vetor(Homem) + Vetor(Mulher) = Vetor(Rainha)")
print("\nA mesma coisa funciona num VAE Bem treinado:")
print("Z_RESULTADO = Z_HOMEM_DE_OCULOS - Z_HOMEM + Z_MULHER")
print("Decoder(Z_RESULTADO) ---> Foto de uma mulher de óculos que não existia antes!")
