# %% [markdown]
# <div style="background: linear-gradient(135deg, #d00000 0%, #ffba08 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🏰 02 — DCGAN e o Pesadelo do Mode Collapse</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 10 · Bloco 02 · GANs</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Construir a GAN Convolucional. E experimentar a maior dor de um engenheiro de ML: ver sua rede colapsar.
#
# ---

# %%
print("Mode Collapse (Colapso de Modo):")
print("Acontece quando o Gerador descobre UM ÚNICO rosto que sempre engana o Policial.")
print("Em vez de aprender a gerar 1000 rostos, ele gera O MESMO rosto milhares de vezes.")
print("É a falha mais comum no treino de GANs.")
