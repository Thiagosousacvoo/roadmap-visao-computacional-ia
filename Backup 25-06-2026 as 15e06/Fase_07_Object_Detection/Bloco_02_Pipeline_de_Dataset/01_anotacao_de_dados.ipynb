# %% [markdown]
# <div style="background: linear-gradient(135deg, #ff9e00 0%, #ff5400 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🏷️ 01 — Anotação e Rotulagem</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 07 · Bloco 02 · Datasets</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Você não programa inteligência, você a treina. Se o seu Dataset tem anotações erradas (Bboxes cortando o carro pela metade), sua IA vai nascer com defeito de visão.
#
# ---

# %% [markdown]
# ## Ferramentas de Trabalho
# 1. **LabelImg:** Uma ferramenta clássica (em Python) para desenhar caixas em fotos no seu próprio computador.
# 2. **Roboflow:** A plataforma Cloud moderna padrão da indústria. Ele divide o dataset, rotula em grupo, e gera as pastas formatadas pro YOLO automaticamente.
