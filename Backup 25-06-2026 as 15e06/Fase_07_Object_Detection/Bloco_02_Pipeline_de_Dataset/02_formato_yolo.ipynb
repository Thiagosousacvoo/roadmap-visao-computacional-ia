# %% [markdown]
# <div style="background: linear-gradient(135deg, #ff9e00 0%, #ff5400 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🗂️ 02 — Estrutura de Pastas (O data.yaml)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 07 · Bloco 02 · Datasets</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# O YOLO é chato. Se as pastas não estiverem organizadas perfeitamente, o treino sequer inicia.
#
# ---

# %%
print("Estrutura obrigatória do YOLO:\n")
print("meu_dataset/")
print("├── images/")
print("│   ├── train/  <-- Suas 500 fotos de treino")
print("│   └── val/    <-- Suas 50 fotos de validação")
print("├── labels/")
print("│   ├── train/  <-- 500 arquivos .txt com os mesmos nomes das imagens")
print("│   └── val/    <-- 50 arquivos .txt com os labels da validação")
print("└── data.yaml   <-- O arquivo de configuração principal")

print("\nDentro do data.yaml:")
print("path: ../meu_dataset")
print("nc: 2")
print("names: ['cachorro', 'gato']")
