# %% [markdown]
# <div style="background: linear-gradient(135deg, #2b9348 0%, #007f5f 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">⚡ 01 — Exportação (Saindo do Python)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 07 · Bloco 06 · Deploy</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# O modelo treinado em `.pt` (PyTorch) é maravilhoso para Python. Mas e se o cliente quiser rodar no celular (iOS/Android)? Ou num micro-pc de 50 dólares (Raspberry)? Precisamos converter as matrizes da rede para **C++ puro** usando os formatos `.onnx` ou `.engine`.
#
# ---

# %%
print("Para converter o seu modelo treinado.pt para a linguagem Universal do ONNX:\n")
print("yolo export model=meu_modelo.pt format=onnx opset=12")
