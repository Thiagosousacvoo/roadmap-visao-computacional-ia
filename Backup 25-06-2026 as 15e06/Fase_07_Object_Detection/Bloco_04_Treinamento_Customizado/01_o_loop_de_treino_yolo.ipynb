# %% [markdown]
# <div style="background: linear-gradient(135deg, #00b4d8 0%, #0077b6 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🏋️ 01 — Treinando o Seu Próprio YOLO</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 07 · Bloco 04 · Custom YOLO</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Chega de caçar cachorros no dataset da COCO. A vida real exige que você treine a rede para detectar Capacetes de Segurança Industrial (EPI). E não usaremos um script de 500 linhas de PyTorch para isso!
#
# ---

# %%
print("A Magia da Ultralytics:\n")
codigo_treino = """
from ultralytics import YOLO

# 1. Carrega um modelo pré-treinado Vazio (NANO)
modelo = YOLO("yolov8n.pt")

# 2. Inicia o Treinamento no nosso arquivo de capacetes
# O YOLO vai automaticamente procurar a GPU, fazer Augmentation e Plotar gráficos!
modelo.train(
    data="meu_dataset_epi/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device=0 # Força o uso da GPU principal
)
"""
print(codigo_treino)
