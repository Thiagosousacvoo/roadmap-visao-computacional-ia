# %% [markdown]
# <div style="background: linear-gradient(135deg, #ff5400 0%, #ff0054 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">📦 01 — O Formato das Caixas (Bbox)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 07 · Bloco 01 · Fundamentos</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Em classificação nós dizíamos: "Isso é um carro".
# Em detecção nós precisamos dizer: "Isso é um carro que começa no pixel X,Y e termina no pixel W,H". O problema é que a indústria não entrou em um consenso sobre como desenhar essas caixas!
#
# ---

# %% [markdown]
# ## 1️⃣ O Padrão Pascal VOC (Absoluto)
# Usa os pixels literais da imagem. `[X_min, Y_min, X_max, Y_max]`
# Exemplo: A pessoa está entre o pixel 150 ao 300.
#
# ## 2️⃣ O Padrão YOLO (Relativo/Normalizado)
# Usa porcentagens de 0 a 1. E não usa as bordas, usa o Centro! `[X_centro, Y_centro, Largura, Altura]`
# Exemplo: O centro da pessoa está exatamente no `0.5` (Meio da imagem). A pessoa ocupa `0.3` (30%) da largura total.

# %%
def converte_pascal_para_yolo(xmin, ymin, xmax, ymax, img_width, img_height):
    # TODO: Tente implementar essa matemática!
    pass
