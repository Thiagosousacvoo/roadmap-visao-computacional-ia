# %% [markdown]
# <div style="background: linear-gradient(135deg, #ef233c 0%, #d90429 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🕵️ 01 — Não Perca o Alvo (Tracking)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 07 · Bloco 05 · Tracking</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Detecção normal tem "Amnésia". No frame 1 ele vê o João. No frame 2 ele vê o João de novo, mas acha que é outra pessoa. Como contamos quantas pessoas passaram pela porta se a rede esquece dos IDs a cada frame?
#
# ---

# %% [markdown]
# ## ByteTrack e Filtro de Kalman
# O Rastreador usa física para "prever" onde a caixa do João estará no Frame 2 baseado na velocidade dele no Frame 1. O ByteTrack é o algoritmo de Tracking padrão integrado na API do YOLO.

# %%
codigo_tracking = """
from ultralytics import YOLO
modelo = YOLO("yolov8n.pt")

# Ao invés de model("video.mp4"), usamos model.track()
resultados = modelo.track(source="video_da_porta.mp4", tracker="bytetrack.yaml")

for r in resultados:
    caixas = r.boxes
    print("Os IDs únicos rastreados neste frame são:", caixas.id)
"""
print("Implementaremos a Contagem no Projeto Final!")
