# %% [markdown]
# <div style="background: linear-gradient(135deg, #390099 0%, #9e0059 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🚀 02 — Inferência Rápida com Ultralytics</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 07 · Bloco 03 · YOLO</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# A empresa Ultralytics transformou o YOLOv8 (e agora o v11) num pacote incrivelmente simples. Nada de loops gigantes de PyTorch para fazer inferência.
#
# ---

# %%
print("Para rodar: pip install ultralytics\n")
codigo_yolo = """
from ultralytics import YOLO

# Baixa os pesos ultra eficientes pré-treinados em 80 categorias do dataset COCO.
modelo = YOLO("yolov8n.pt") # O 'n' significa NANO. Rápido e leve!

# Detecta tudo que está na imagem.
resultados = modelo("minha_foto_da_rua.jpg")

for r in resultados:
    r.show() # Mostra a imagem com as caixas coloridas renderizadas!
"""
print(codigo_yolo)
