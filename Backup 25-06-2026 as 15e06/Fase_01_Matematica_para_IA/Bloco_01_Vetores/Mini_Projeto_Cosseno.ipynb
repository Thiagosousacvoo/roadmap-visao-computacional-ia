# %% [markdown]
# <div style="background: linear-gradient(135deg, #343a40 0%, #6c757d 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🎯 Mini Projeto — Motor de Recomendação Baseado em Cosseno</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 01 · Bloco 01 · Vetores</p>
# </div>

# %% [markdown]
# ## O Problema
#
# Você tem um Dicionário de Produtos. Cada produto foi codificado por uma Inteligência Artificial em um "Embedding" de 5 dimensões numéricas.
#
# Seu desafio é:
# 1. O usuário está vendo a "Câmera Canon".
# 2. Crie uma função que encontre qual é o **outro produto mais similar** do catálogo, baseado na similaridade de cosseno.
#
# **Regra:** Não use bibliotecas de IA, use apenas `numpy`.

# %%
import numpy as np

# [Preço, Portabilidade, Zoom, Bateria, Lente_Intercambiável]
catalogo = {
    "Câmera Canon":  np.array([0.8, 0.4, 0.9, 0.7, 1.0]),
    "GoPro":         np.array([0.5, 1.0, 0.2, 0.9, 0.0]),
    "Lente 50mm":    np.array([0.3, 0.6, 0.1, 0.0, 1.0]),
    "Câmera Nikon":  np.array([0.8, 0.3, 0.9, 0.8, 1.0]),
    "Tripé":         np.array([0.1, 0.5, 0.0, 0.0, 0.0]),
}

def similaridade(v1, v2):
    # TODO: Implemente a matemática do cosseno
    pass

def recomendar_similar(nome_produto, base_dados):
    # TODO: Itere pelo catálogo, calcule a similaridade do produto alvo com todos os outros
    # Guarde qual foi o que teve o maior score e não esqueça de não recomendar o próprio produto!
    pass

# Testando seu código:
# recomendar_similar("Câmera Canon", catalogo)
# Deveria retornar "Câmera Nikon"!
