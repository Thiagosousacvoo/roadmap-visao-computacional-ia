# %% [markdown]
# <div style="background: linear-gradient(135deg, #343a40 0%, #6c757d 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🎯 Mini Projeto — Desenhando o Eigen-espaço</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 01 · Bloco 05 · Autovalores</p>
# </div>

# %% [markdown]
# ## O Problema
#
# Dada a matriz de expansão abaixo, use matplotlib para plotar os dois Autovetores que você calcular com NumPy, originando-se do (0,0).
#
# Visualizar a matemática aterra o aprendizado na mente!

# %%
import numpy as np
import matplotlib.pyplot as plt

A = np.array([
    [3, 1],
    [0, 2]
])

# Seu código aqui para achar autovetores/autovalores
# vals, vecs = ...

# Desenhe os vetores na tela usando plt.quiver
