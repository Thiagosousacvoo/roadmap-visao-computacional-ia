# %% [markdown]
# <div style="background: linear-gradient(135deg, #212529 0%, #343a40 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🔬 Sandbox de Exploração - PCA</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 01 · Projeto Final</p>
# </div>

# %% [markdown]
# ## 🎯 O Sandbox do Projeto (PCA)
#
# Neste ambiente, você tentará aplicar os passos do Algoritmo PCA puros no `dataset_iris_reduzido.csv`.
#
# **O Passo a Passo do PCA:**
# 1. Centralizar os dados (Subtrair a média de cada coluna).
# 2. Calcular a Matriz de Covariância.
# 3. Extrair os Autovalores e Autovetores da Matriz de Covariância.
# 4. Ordenar do maior Autovalor para o menor.
# 5. Projetar os dados originais nos Autovetores principais multiplicando as matrizes.
#
# Quando estiver funcionando, abstraia tudo numa classe em `src/pca.py`!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 1. Carregando os dados
# df = pd.read_csv("data/raw/dataset_iris_reduzido.csv")
# X = df.drop("target", axis=1).values
# y = df["target"].values

print("Sandbox pronto! Comece a implementar os 5 passos do PCA.")
