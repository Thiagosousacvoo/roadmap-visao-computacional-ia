# %% [markdown]
# <div style="background: linear-gradient(135deg, #343a40 0%, #6c757d 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🎯 Mini Projeto — Descida do Gradiente Manual</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 01 · Bloco 06 · Cálculo</p>
# </div>

# %% [markdown]
# ## O Problema
#
# Você tem a função de custo: $f(x) = x^2 + 5$.
# O mínimo óbvio é $x = 0$ (onde $f(0) = 5$).
# Mas nós faremos o Computador encontrar esse valor **sozinho**, dando "passinhos" usando a derivada!
#
# **Fórmula de Atualização:**
# $x_{novo} = x_{atual} - (LearningRate \times Derivada(x_{atual}))$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Função Custo
def f(x):
    return x**2 + 5

# TODO 1: Implemente a Derivada (f'(x) = 2x)
def df(x):
    pass # Seu código aqui

# TODO 2: Crie o loop de treinamento
x_chute = 4.0 # Começamos muito longe do zero (erro alto)
learning_rate = 0.1
epocas = 20

historico_x = [x_chute]
historico_y = [f(x_chute)]

# for _ in range(epocas):
#     gradiente = df(x_chute)
#     x_chute = x_chute - (learning_rate * gradiente)
#     historico_x.append(x_chute)
#     historico_y.append(f(x_chute))

# print(f"O computador encontrou o fundo do vale no ponto X={x_chute:.4f}")

# TODO 3: Plote a função f(x) e espalhe (plt.scatter) os pontos do historico_x para ver a "bolinha caindo"
