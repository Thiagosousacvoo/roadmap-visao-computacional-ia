# %% [markdown]
# <div style="background: linear-gradient(135deg, #343a40 0%, #6c757d 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🎯 Mini Projeto — Transformações Sequenciais</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 01 · Bloco 04 · Transformações</p>
# </div>

# %% [markdown]
# ## O Problema
#
# Quando rotacionamos, ampliamos e deslocamos uma imagem de Raio-X em um modelo médico, estamos aplicando dezenas de matrizes.
# - O poder da álgebra linear é que `(M_escala @ M_rotacao) @ Ponto` é a mesma coisa que `Matriz_Unificada @ Ponto`.
#
# Você deve criar uma matriz unificada que aplique **Escala e Rotação** simultaneamente em um vetor!

# %%
import numpy as np
import matplotlib.pyplot as plt

ponto_base = np.array([1.0, 1.0])

# TODO 1: Crie uma matriz de escala que dobre o tamanho dos dois eixos
# M_escala = ...

# TODO 2: Crie uma matriz de rotação para 45 Graus (np.pi/4)
# theta = np.pi/4
# M_rotacao = ...

# TODO 3: Combine-as (Atenção para a ordem! M_rotacao @ M_escala produzirá um efeito diferente de M_escala @ M_rotacao)
# M_combo = ...

# TODO 4: Aplique no ponto_base
# ponto_final = M_combo @ ponto_base
