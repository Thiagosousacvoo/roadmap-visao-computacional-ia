# %% [markdown]
# <div style="background: linear-gradient(135deg, #343a40 0%, #6c757d 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🚀 Projeto 2: Mágica do Chroma Key</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 03 · Projetos</p>
# </div>

# %% [markdown]
# ## O Desafio
# Usando OpenCV puro (rode como script se preferir), use `cv2.inRange` no espaço HSV para apagar o fundo de uma imagem ou destacar apenas as partes "Amarelas".
