# %% [markdown]
# <div style="background: linear-gradient(135deg, #3a0ca3 0%, #7209b7 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🎯 Mini Projeto — Brilho Matemático</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 03 · Bloco 01 · Matrizes</p>
# </div>

# %% [markdown]
# ## O Desafio
#
# Crie uma matriz cinza escuro de tamanho 100x100 (valores 50).
# Aumente o brilho dessa imagem somando 220 em todos os pixels.
#
# **O GRANDE PROBLEMA:** Como a matriz é `uint8` (0 a 255), se você somar 50 + 220, o número tentará virar 270. No formato `uint8`, ele "dá a volta" (overflow) e o pixel vira 14 (quase preto de novo!!).
#
# Use a função `np.clip()` do NumPy para impedir que os números passem de 255!

# %%
import numpy as np
import matplotlib.pyplot as plt

img_escura = np.full((100, 100), 50, dtype=np.uint8)

# TODO: Aplique o brilho de +220 de forma segura usando np.clip
# dica: voce terá que somar numa variavel float (ou int16) primeiro, dar clip(0, 255), e depois .astype(np.uint8)

# img_brilho = ...

# plt.imshow(img_brilho, cmap="gray", vmin=0, vmax=255)
# plt.show()
