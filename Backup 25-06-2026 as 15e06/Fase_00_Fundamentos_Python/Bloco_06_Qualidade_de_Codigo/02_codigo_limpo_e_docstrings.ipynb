# %% [markdown]
# <div style="background: linear-gradient(135deg, #dc3545 0%, #fd7e14 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">✨ 02 — Clean Code & Docstrings</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 00 · Bloco 06 · Qualidade</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Escrever código que o computador entende é fácil. Difícil é escrever código que O OUTRO DESENVOLVEDOR entenda.
# - Padrão Google de Docstrings.
# - Nomes de variáveis semânticas.
#
# ---

# %% [markdown]
# ## 1️⃣ Docstrings Profissionais (Padrão Google)
#
# Toda função importante deve documentar seus parâmetros (`Args:`) e retornos (`Returns:`).

# %%
def carregar_pesos_modelo(caminho_arquivo: str, usar_gpu: bool = True) -> dict:
    """
    Carrega os pesos de um modelo de IA a partir do disco.

    Args:
        caminho_arquivo (str): Caminho absoluto para o arquivo .pth ou .h5.
        usar_gpu (bool, optional): Se True, move os tensores para a VRAM. Padrão: True.

    Returns:
        dict: Um dicionário contendo o nome das camadas e seus pesos (tensores).
        
    Raises:
        FileNotFoundError: Se o arquivo especificado não existir.
    """
    pass

print(carregar_pesos_modelo.__doc__)

# %% [markdown]
# ## 2️⃣ Clean Code: Semântica em vez de Comentários Obvios
#
# Variáveis com letras soltas (`a`, `x`, `df2`) matam a legibilidade. O código deve ser tão bem escrito que não precise de comentários explicando *o que* ele faz, apenas *por que* faz.

# %%
# ❌ Ruim
# Filtra x menor que 10 e calcula y
df2 = df[df['x'] < 10]
for i in range(len(df2)):
    df2['y'][i] = df2['z'][i] * 2

# ✅ Bom (Numpy Style)
clientes_ativos = dados_clientes[dados_clientes['meses_inatividade'] < 10]
clientes_ativos['score_risco'] = clientes_ativos['score_credito'] * 2
