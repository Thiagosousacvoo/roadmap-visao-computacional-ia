# %% [markdown]
# <div style="background: linear-gradient(135deg, #2a9d8f 0%, #264653 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🔤 01 — Tokenização (Como IA lê Letras)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 06 · Bloco 01 · Texto</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Redes Neurais só engolem números. A forma ingênua seria "A=1, B=2, C=3". A forma moderna e eficiente é quebrar frases inteiras em pedaços comuns chamados Subwords (Tokens).
#
# ---

# %%
print("Para rodar o código real, no futuro você fará: pip install transformers")
print("O AutoTokenizer do HuggingFace é o padrão da indústria.")
texto = "Um cachorro correndo no parque"
print(f"Texto original: {texto}")
print(f"Texto Tokenizado (Simulação BERT): [101, 1041, 3232, 102]")
