# %% [markdown]
# <div style="background: linear-gradient(135deg, #2a9d8f 0%, #264653 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🌌 02 — O Espaço Latente (Embeddings)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 06 · Bloco 01 · Texto</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Tokenizar "Cachorro" para `3232` não ensina pra IA que Cachorro late. Precisamos transformar esse número isolado num grande VETOR geográfico.
#
# ---

# %% [markdown]
# ## A Magia da Semântica
# Se "Rei" é `[1.0, 0.0]` e "Homem" é `[0.5, 0.0]`, a IA aprende que `Rei - Homem + Mulher = Rainha`. A distância geométrica entre os vetores (Embeddings) carrega o significado no espaço multidimensional!
