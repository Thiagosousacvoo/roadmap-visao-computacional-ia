# %% [markdown]
# <div style="background: linear-gradient(135deg, #118ab2 0%, #073b4c 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🤗 01 — O Padrão Ouro: Hugging Face</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 06 · Bloco 06 · Prática</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Ninguém implementa *Self-Attention* na unha no trabalho. O mundo inteiro usa o pacote `transformers` da Hugging Face.
#
# ---

# %%
print("A Hugging Face é o 'GitHub' da Inteligência Artificial. Para usar o CLIP na vida real:\n")

codigo_huggingface = """
from transformers import CLIPProcessor, CLIPModel
from PIL import Image

# 1. Baixa o modelo da Internet em Segundos
modelo = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processador = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# 2. Roda a Mágica Zero-Shot
inputs = processador(text=["um gato", "um cachorro"], images=foto_real, return_tensors="pt", padding=True)
outputs = modelo(**inputs)
probs = outputs.logits_per_image.softmax(dim=1)
"""
print(codigo_huggingface)
