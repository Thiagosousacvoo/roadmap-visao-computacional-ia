# %% [markdown]
# <div style="background: linear-gradient(135deg, #ffb703 0%, #fb8500 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">📦 01 — O Git não aguenta IA</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 09 · Bloco 04 · DVC</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Se você tentar dar `git push` num modelo `.pt` de 500MB, o Github vai te bloquear. Se tentar dar push em 10 mil imagens de treino, pior ainda. Conheça o **DVC (Data Version Control)**.
#
# ---

# %%
print("O Fluxo de Trabalho do DVC:\n")
print("1. Você dá o comando: dvc add dataset/")
print("2. O DVC compacta as fotos e envia pra nuvem (AWS S3 ou Google Drive).")
print("3. O DVC gera um arquivo minúsculo de texto chamado 'dataset.dvc'.")
print("4. Você dá 'git commit' APENAS neste arquivinho de texto!")
print("\nSe você quiser voltar o código para o mês passado, o DVC vai ler o arquivinho daquela época e baixar o dataset exato daquele dia!")
