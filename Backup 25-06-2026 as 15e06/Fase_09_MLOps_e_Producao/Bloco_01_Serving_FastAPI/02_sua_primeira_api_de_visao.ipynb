# %% [markdown]
# <div style="background: linear-gradient(135deg, #f77f00 0%, #d62828 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🌐 02 — O Endpoint de Inferência</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 09 · Bloco 01 · FastAPI</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Vamos parar de chamar arquivos no disco e vamos receber requisições POST com binários de Imagem diretamente do cliente.
#
# ---

# %% [markdown]
# > ⚠️ **A ARMADILHA DO LOAD DE MODELO:**
# > Jamais, sob nenhuma hipótese, coloque o comando `modelo = torch.load("pesos.pt")` **dentro** da função do seu endpoint! Isso faria o servidor alocar 2GB na placa de vídeo para cada cliente que chamasse a rota.
# > **O modelo deve ser instanciado UMA ÚNICA VEZ antes do servidor iniciar.**

# %%
print("Exemplo da rota de Visão Computacional:\n")
print("@app.post('/detectar')")
print("async def detectar(file: UploadFile = File(...)):")
print("    contents = await file.read()")
print("    # Converte o binário da internet para uma Imagem que o modelo entenda")
print("    img = Image.open(BytesIO(contents)).convert('RGB')")
print("    # Inferência Global e Resposta em JSON")
print("    return { 'bounding_boxes': model(img) }")
