# %% [markdown]
# <div style="background: linear-gradient(135deg, #f77f00 0%, #d62828 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🚀 01 — A Morte do Flask em IA</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 09 · Bloco 01 · FastAPI</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Durante anos o mundo de Python usou Flask para APIs Web. Mas quando o arquivo da requisição é um Vídeo de 50MB passando por uma ResNet, o sistema trava. O FastAPI nasceu para dominar I/O assíncrono e tipagem estrita (Pydantic).
#
# ---

# %%
print("Para rodar uma API moderna no terminal, usaremos:")
print("pip install fastapi uvicorn python-multipart\n")
print("E executaremos com o servidor Asynchronous Server Gateway Interface (ASGI):")
print("uvicorn api:app --host 0.0.0.0 --port 8000")
