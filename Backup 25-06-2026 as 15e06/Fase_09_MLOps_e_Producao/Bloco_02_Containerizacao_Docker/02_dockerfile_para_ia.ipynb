# %% [markdown]
# <div style="background: linear-gradient(135deg, #0077b6 0%, #023e8a 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">📜 02 — A Receita de Bolo (Dockerfile)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 09 · Bloco 02 · Docker</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# Criar um Dockerfile para uma calculadora em Python é fácil. Criar um Dockerfile para o PyTorch e OpenCV exige contornar algumas falhas de biblioteca do sistema operacional C/C++.
#
# ---

# %%
print("Para rodar o OpenCV (cv2) na nuvem, seu Dockerfile precisa desta linha mágica que instala as dependências gráficas que não existem em servidores:")
print("\nRUN apt-get update && apt-get install -y libglib2.0-0 libsm6 libxext6 libxrender-dev libgl1-mesa-glx")
