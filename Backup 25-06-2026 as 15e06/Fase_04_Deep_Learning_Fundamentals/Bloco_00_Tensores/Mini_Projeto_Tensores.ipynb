# %% [markdown]
# <div style="background: linear-gradient(135deg, #5f0f40 0%, #310a1b 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🎯 Mini Projeto — Tradutor de NumPy</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 04 · Bloco 00 · Tensores</p>
# </div>

# %% [markdown]
# ## O Desafio
#
# Escreva um script usando `torch` que crie duas matrizes 3x3 normais (aleatórias), multiplique elas, e printe o resultado. Só que não vale usar NumPy!

# %%
import torch

# TODO: Crie matriz_A e matriz_B com torch.randn(3, 3)
# TODO: Faça a multiplicação matricial real (não element-wise) usando torch.matmul() ou o operador @
