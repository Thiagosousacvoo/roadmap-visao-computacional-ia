# %% [markdown]
# <div style="background: linear-gradient(135deg, #140036 0%, #000000 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🎯 Mini Projeto — MLP Puramente Matemático</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 04 · Bloco 02 · Backprop</p>
# </div>

# %% [markdown]
# ## O Desafio Final antes do PyTorch
#
# Construa um Multilayer Perceptron (MLP) com 1 Camada Oculta APENAS usando `numpy`. Você fará a matemática da Forward, do Custo e da Backprop. (Siga a colinha de derivadas que deixei aqui).

# %%
import numpy as np

def sigmoid(x): return 1 / (1 + np.exp(-x))
def sigmoid_deriv(x): return x * (1 - x)

# TODO: Crie X e y usando matrizes Numpy aleatórias (ex: X_train (4,2), y_train (4,1) portão XOR)
# TODO: Inicialize w1 (2, 3) e w2 (3, 1) com números aleatórios baixos.
# TODO: Loop for épocas.
#       - Forward pass (a1 = sigmoid(X @ w1), y_pred = sigmoid(a1 @ w2))
#       - Erro: error_out = y - y_pred
#       - Backprop: 
#              delta_out = error_out * sigmoid_deriv(y_pred)
#              error_h = delta_out @ w2.T
#              delta_h = error_h * sigmoid_deriv(a1)
#       - Atualização dos Pesos (w2 += a1.T @ delta_out, w1 += X.T @ delta_h)
