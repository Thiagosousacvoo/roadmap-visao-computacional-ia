# %% [markdown]
# <div style="background: linear-gradient(135deg, #0077b6 0%, #00b4d8 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🛡️ 03 — Dropout e BatchNorm</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 04 · Bloco 03 · Treinamento</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos deste notebook
#
# A rede neural é mestre em "decorar" o dataset. Para forçar o aprendizado real, usamos `Dropout`.
# O Dropout age como um professor sádico que amarra o braço direito de um aluno. O aluno é forçado a aprender a usar o braço esquerdo! (A rede desliga 30% dos neurônios aleatoriamente a cada rodada).

# %%
import torch.nn as nn

# Dropout com 50% de chance de matar o neurônio!
camada_dropout = nn.Dropout(p=0.5)

# Batch Norm padroniza o fluxo matemático entre as camadas!
camada_norm = nn.BatchNorm1d(num_features=128)
