# %% [markdown]
# <div style="background: linear-gradient(135deg, #370617 0%, #6a040f 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">💎 02 — Elevando as Fases a Nível de Produção</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 12 · Bloco 01 · A Regra de Ouro</p>
# </div>

# %% [markdown]
# ## 🎯 O Plano de Ação
#
# Você não precisa criar 10 projetos novos. Você precisa de **três** excelentes. Vamos voltar nas fases passadas e escolher:
#
# ---

# %% [markdown]
# ### Projetos Recomendados
# 1. **O MLOps da Fase 09**: Suba aquela API que rodava com o Docker.
# 2. **O NeRF/Splatting da Fase 11**: Mostre que você constrói 3D.
# 3. **A Segmentação Médica da Fase 08**: Treine com um dataset do Kaggle (como Brain Tumor) e documente as loss functions usadas.
