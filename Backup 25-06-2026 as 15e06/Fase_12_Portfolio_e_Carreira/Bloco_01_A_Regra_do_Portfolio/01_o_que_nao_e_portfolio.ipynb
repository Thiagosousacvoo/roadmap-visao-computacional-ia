# %% [markdown]
# <div style="background: linear-gradient(135deg, #370617 0%, #6a040f 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🚫 01 — O Cemitério dos Projetos</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 12 · Bloco 01 · A Regra de Ouro</p>
# </div>

# %% [markdown]
# ## 🎯 Por que seu currículo é ignorado?
#
# Ter um GitHub cheio de "Calculadora em Python" ou "Reconhecimento de Dígitos MNIST" não atrai Recrutadores. Pior, isso mostra que você é apenas um júnior que copia tutoriais.
#
# ---

# %% [markdown]
# ### A Regra de Ouro do Portfólio
# **Cada projeto de portfólio deve ter um usuário hipotético que se beneficiaria dele.**
#
# ❌ *Errado:* Treinei a YOLOv8 com 90% de Acurácia.
# ✅ *Certo:* Criei um Sistema de Segurança para Fábricas Industriais que dispara um alarme via API caso um funcionário seja detectado sem EPI.
