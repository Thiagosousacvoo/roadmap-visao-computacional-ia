# %% [markdown]
# <div style="background: linear-gradient(135deg, #2b2d42 0%, #8d99ae 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">😎 02 — Seu Currículo Central no Github</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 12 · Bloco 02 · Github</p>
# </div>

# %% [markdown]
# ## 🎯 O README do seu Profile
#
# No Github, se você criar um repositório com o mesmo nome do seu usuário (ex: `thiago/thiago`), o README dele aparece na sua Home.
#
# ---

# %% [markdown]
# ### O Hub da IA
# Coloque um link para a sua conta no **HuggingFace**. Faça o upload do arquivo de Pesos `.pt` de um modelo que você treinou e crie um "Gradio Space" gratuito lá para que o recrutador teste a sua IA no navegador dele sem ter que instalar nada!
