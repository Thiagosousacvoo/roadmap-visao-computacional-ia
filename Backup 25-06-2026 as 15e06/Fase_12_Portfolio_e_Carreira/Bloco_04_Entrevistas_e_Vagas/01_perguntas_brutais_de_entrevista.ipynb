# %% [markdown]
# <div style="background: linear-gradient(135deg, #5f0f40 0%, #9a031e 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">⚔️ 01 — A Sabatina do CTO</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 12 · Bloco 04 · Entrevistas</p>
# </div>

# %% [markdown]
# ## 🎯 O Filtro Técnico
#
# Eles não vão perguntar "o que é Python". Eles vão perguntar: "O modelo quebrou em Produção por causa de Data Drift, o que você faz?"
#
# ---

# %% [markdown]
# ### Respostas Ancoradas
# Nunca responda apenas a teoria. Responda ancorando nos projetos que você fez aqui:
# *Entrevistador:* "O que você sabe sobre Otimização de GPU?"
# *Você:* "Na teoria eu conheço TensorRT. Na prática, eu otimizei um modelo ONNX na Fase 09 e cortei a latência de 80ms para 15ms."
