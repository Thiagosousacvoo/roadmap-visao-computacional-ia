# %% [markdown]
# <div style="background: linear-gradient(135deg, #5f0f40 0%, #9a031e 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">💰 02 — Destruindo o Teste Prático</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 12 · Bloco 04 · Entrevistas</p>
# </div>

# %% [markdown]
# ## 🎯 O Desafio de 3 Dias
#
# A maioria das startups de IA manda um Take-Home Project. Eles querem ver se você codifica limpo, e não apenas se acerta a acurácia.
#
# ---

# %% [markdown]
# ### Negociação
# Nunca aceite a primeira oferta. Use as suas métricas de portfólio para ancorar o seu valor técnico. Você tem deploy, tem modelos próprios, e você entende de ponta a ponta.
