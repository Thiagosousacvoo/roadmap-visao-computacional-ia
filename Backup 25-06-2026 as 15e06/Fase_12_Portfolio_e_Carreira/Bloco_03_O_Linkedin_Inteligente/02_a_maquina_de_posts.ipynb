# %% [markdown]
# <div style="background: linear-gradient(135deg, #0077b5 0%, #00a0dc 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🗣️ 02 — O Método de Ensino Aberto</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 12 · Bloco 03 · LinkedIn</p>
# </div>

# %% [markdown]
# ## 🎯 Construa em Público
#
# Não poste apenas o certificado deste curso. Poste **COMO** você implementou o NeRF. Poste como você resolveu um bug no Docker.
#
# ---

# %% [markdown]
# A indústria tem pavor de Júniores que só sabem rodar `model.fit()`. Quando você escreve um post explicando por que você trocou o `BCE Loss` pelo `Focal Loss` na Fase 08, os CTOs começam a seguir você.
