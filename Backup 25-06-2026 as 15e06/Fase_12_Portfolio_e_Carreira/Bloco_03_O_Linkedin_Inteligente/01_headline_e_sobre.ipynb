# %% [markdown]
# <div style="background: linear-gradient(135deg, #0077b5 0%, #00a0dc 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">💼 01 — Hackeando Buscas de Headhunters</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 12 · Bloco 03 · LinkedIn</p>
# </div>

# %% [markdown]
# ## 🎯 Seu Título é a sua Ferramenta de Vendas
#
# Recrutadores buscam palavras-chave. Eles digitam "PyTorch", "Computer Vision" e "Segmentação" no painel deles.
#
# ---

# %% [markdown]
# ### Headline Otimizada
# ❌ "Estudante de Engenharia" (Invisível)
# ✅ "Engenheiro de Visão Computacional | PyTorch, YOLO e MLOps" (Imã de vagas)
