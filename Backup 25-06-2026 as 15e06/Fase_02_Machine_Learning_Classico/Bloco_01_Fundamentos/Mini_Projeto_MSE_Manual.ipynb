# %% [markdown]
# <div style="background: linear-gradient(135deg, #94d2bd 0%, #0a9396 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🎯 Mini Projeto — Calculadora de Custo</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 02 · Bloco 01 · Fundamentos</p>
# </div>

# %% [markdown]
# ## O Desafio
#
# Você é o coração da Rede Neural. Crie uma função que receba o vetor real, o vetor predito, calcule o MSE (Mean Squared Error) e o MAE (Mean Absolute Error) puramente com NumPy.
#
# *Nota: O MAE (Erro Absoluto Médio) não eleva ao quadrado, ele apenas tira o módulo dos erros (np.abs)*.

# %%
import numpy as np

def calcular_metricas(y_true, y_pred):
    # TODO 1: Implemente o MSE puramente em numpy (Sem usar loops for!)
    # mse = ...

    # TODO 2: Implemente o MAE puramente em numpy
    # mae = ...
    pass

y_verdadeiros = np.array([1.5, 2.0, 3.5, 4.0])
y_chutes      = np.array([1.0, 2.5, 3.5, 5.0])

# Teste sua função!
# calcular_metricas(y_verdadeiros, y_chutes)
