# %% [markdown]
# <div style="background: linear-gradient(135deg, #bb3e03 0%, #9b2226 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🎯 Mini Projeto — Guerra de Algoritmos</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 02 · Bloco 02 · Algoritmos</p>
# </div>

# %% [markdown]
# ## O Desafio
#
# Crie um dataset de "Luas Entrelaçadas" e treine Três modelos (Regressão Logística, Random Forest, e SVM) para separar essas luas.
# Plot as fronteiras de decisão (Decision Boundaries) de cada modelo para vermos visualmente quem é linear e quem se molda ao formato dos dados!

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

# Gerador poderoso do sklearn para desafios de IA
X, y = make_moons(n_samples=300, noise=0.15, random_state=42)

plt.scatter(X[:,0], X[:,1], c=y, cmap='winter', edgecolors='k')
plt.title("A Complexidade: Nenhuma linha reta consegue separar as bolinhas perfeitas!")
plt.show()

# TODO: Treine um LogisticRegression(X, y). Ele vai ser forçado a cortar no meio numa reta.
# TODO: Treine um RandomForestClassifier(X, y).
# TODO: Treine um SVC(kernel="rbf").
