# %% [markdown]
# <div style='background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%); padding: 30px; border-radius: 15px; box-shadow: 0 10px 20px rgba(0,0,0,0.3); color: white; border-left: 5px solid #00f2fe;'>
#     <h1 style='margin:0; font-family: "Segoe UI", sans-serif; font-weight: 800; letter-spacing: 2px; font-size: 2.5em; text-transform: uppercase; text-shadow: 2px 2px 4px rgba(0,0,0,0.5);'>
#         🚀 Trilha de IA: O Guia Definitivo
#     </h1>
#     <p style='margin: 15px 0 0 0; font-family: "Courier New", monospace; font-size: 1.2em; opacity: 0.9; border-top: 1px solid rgba(255,255,255,0.2); padding-top: 10px;'>
#         Do Zero ao Deployment — Construindo o Futuro
#     </p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - Como processar RTSP de câmeras de segurança
# - Decodificação em Hardware (NVIDIA NVDEC)

# %% [markdown]
# ## 1️⃣ O Gargalo do Video
#
# Ler um stream de vídeo RTSP com `cv2.VideoCapture` e processar frame a frame trava tudo na CPU. Para produção real, a decodificação do MP4/RTSP deve ser feita direto dentro da Placa de Vídeo usando GStreamer ou NVIDIA DeepStream.

# %%
print('NVIDIA DeepStream converte o RTSP da câmera direto para o tensor do TensorRT DENTRO da VRAM da GPU, sem nunca tocar na memória RAM da placa mãe. É assim que 1 placa de vídeo lida com 60 câmeras 1080p simultaneamente.')

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. Processar 30 FPS é inútil se o objeto passa devagar pela tela (ex: fila de mercado). Como podemos otimizar o processamento reduzindo o FPS inferido sem perder a acurácia de negócios?
