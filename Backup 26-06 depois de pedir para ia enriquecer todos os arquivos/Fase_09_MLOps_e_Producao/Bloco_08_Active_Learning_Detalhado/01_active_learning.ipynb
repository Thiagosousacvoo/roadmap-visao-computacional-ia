# %% [markdown]
# <div style='background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%); padding: 30px; border-radius: 15px; box-shadow: 0 10px 20px rgba(0,0,0,0.3); color: white; border-left: 5px solid #00f2fe;'>
#     <h1 style='margin:0; font-family: "Segoe UI", sans-serif; font-weight: 800; letter-spacing: 2px; font-size: 2.5em; text-transform: uppercase; text-shadow: 2px 2px 4px rgba(0,0,0,0.5);'>
#         🚀 Trilha de IA: O Guia Definitivo
#     </h1>
#     <p style='margin: 15px 0 0 0; font-family: "Courier New", monospace; font-size: 1.2em; opacity: 0.9; border-top: 1px solid rgba(255,255,255,0.2); padding-top: 10px;'>
#         Do Zero ao Deployment — Construindo o Futuro
#     </p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - Human-in-the-Loop
# - Estratégias de amostragem de incerteza

# %% [markdown]
# ## 1️⃣ A IA Pedindo Ajuda
#
# Em produção, recebemos milhões de fotos. Qual devo rotular para treinar a V2 do modelo? Apenas as que o modelo teve dúvidas!

# %%
print('Uncertainty Sampling:')
print('Se Confiança < 60%, envie a imagem para a pasta_de_revisao_humana')
print('Assim, os anotadores não perdem tempo confirmando que um céu azul é um céu azul, e focam só nos corner-cases bizarros.')

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. O que é o *Entropy Sampling* quando o modelo prevê probabilidades para múltiplas classes?
