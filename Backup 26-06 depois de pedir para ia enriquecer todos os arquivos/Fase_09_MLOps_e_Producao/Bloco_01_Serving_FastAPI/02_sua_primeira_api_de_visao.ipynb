# %% [markdown]
# <div style="background: linear-gradient(135deg, #f77f00 0%, #d62828 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🌐 02 — O Endpoint de Inferência</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 09 · Bloco 01 · FastAPI</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - Criar uma API real que recebe uma imagem, passa no modelo e devolve Bounding Boxes.
# - Padrões de design para carregar o modelo.
#
# ---

# %% [markdown]
# ## 1️⃣ A Regra de Ouro do Deploy
#
# **NUNCA carregue o modelo dentro da função da rota.** Carregar um `.pt` do disco para a RAM/VRAM demora segundos. Isso deve ser feito **1 única vez** quando o servidor liga.

# %%
# pip install fastapi uvicorn python-multipart
"""
from fastapi import FastAPI, File, UploadFile
from io import BytesIO
from PIL import Image
import numpy as np
# from ultralytics import YOLO  # Descomente para testar real

app = FastAPI(title='API de Detecção')

# Carrega na memória global UMA VEZ
print('Carregando modelo na GPU...')
# model = YOLO('yolov8n.pt') 
print('Modelo Pronto!')

@app.post('/detectar')
async def predict(file: UploadFile = File(...)):
    # Ler bytes em memória (sem salvar no HD, economiza I/O)
    imagem_bytes = await file.read()
    img = Image.open(BytesIO(imagem_bytes)).convert('RGB')
    
    # results = model(img) # Inferência real
    # mock de resposta:
    return {'status': 'success', 'boxes': [[10, 20, 100, 200]], 'class': 'gato'}
"""
print('Salve o código acima num arquivo app.py e rode com: uvicorn app:app --reload')

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. Por que usamos `BytesIO` em vez de fazer `file.save('temp.jpg')` e ler com OpenCV?
#
# ### Q2. Se uma imagem de 15MB for enviada para a API, qual será o impacto na memória RAM do servidor?
