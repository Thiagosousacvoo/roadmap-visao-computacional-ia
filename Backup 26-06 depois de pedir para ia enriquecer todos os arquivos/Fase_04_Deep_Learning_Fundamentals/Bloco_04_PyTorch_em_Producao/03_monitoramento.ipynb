# %% [markdown]
# <div style="background: linear-gradient(135deg, #ff9f1c 0%, #ffbf69 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">📈 03 — Monitoramento e TensorBoard</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 04 · Bloco 04 · PyTorch</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - Como desligar gradientes no momento de Validação/Teste
# - Guardar históricos para plotar gráficos
# - Salvar e carregar pesos do modelo (`.pth`)
#
# ---

# %% [markdown]
# ## 1️⃣ O Loop de Validação
#
# No teste/validação, a rede não aprende. Não queremos perder tempo calculando backprop, e queremos desligar Dropout.

# %%
import torch
import torch.nn as nn

# modelo = MLP() ...
"""
modelo.eval()  # Desliga Dropout e congela BatchNorm!
with torch.no_grad():  # Desliga a máquina de gradientes (economiza RAM e CPU)
    preds = modelo(x_val)
    loss_val = criterio(preds, y_val)
    
    # Cálculo de Accuracy...
    _, idx_classe = torch.max(preds, dim=1)
    acertos = (idx_classe == y_val).sum().item()
"""
print('Nunca esqueça do modelo.eval() e torch.no_grad() na validação!')

# %% [markdown]
# ## 2️⃣ Salvando e Carregando o Modelo
#
# Após horas de treino, não queremos perder a rede se a luz cair! Salvamos o `state_dict` (dicionário de pesos).

# %%
# Salvando
# torch.save(modelo.state_dict(), 'meu_modelo.pth')

# Carregando
# modelo_novo = MLP()
# modelo_novo.load_state_dict(torch.load('meu_modelo.pth'))
# modelo_novo.eval()  # Pronto para inferência
print('Modelos PyTorch usam extensões .pth ou .pt')

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. Crie um script completo que simule um loop de 10 épocas, contendo Treino e Validação, salvando as duas perdas em listas e plotando no fim.
#
# ### Q2. Pesquise sobre 'Model Checkpointing'. Como salvar O MELHOR modelo e não apenas o modelo da última época?

# %%
# Resolva aqui
