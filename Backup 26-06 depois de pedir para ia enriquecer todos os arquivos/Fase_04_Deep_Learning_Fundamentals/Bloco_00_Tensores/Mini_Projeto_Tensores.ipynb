# %% [markdown]
# <div style="background: linear-gradient(135deg, #5f0f40 0%, #310a1b 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🎯 Mini Projeto — Tradutor de NumPy</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 04 · Bloco 00 · Tensores</p>
# </div>

# %% [markdown]
# ## 🎯 Mini-Projeto: Clonando o NumPy no PyTorch
#
# Sua missão é traduzir operações clássicas de NumPy para PyTorch.
# ---

# %%
import numpy as np
import torch

# 1. Multiplicação de matrizes
np_A = np.random.randn(3, 4)
np_B = np.random.randn(4, 2)
np_res = np.dot(np_A, np_B)

# IMPLEMENTE EM PYTORCH AQUI:
pt_A = torch.from_numpy(np_A)
pt_B = torch.from_numpy(np_B)
# pt_res = ...

# %%
# 2. Soma no eixo 0 (Soma por colunas)
np_soma = np.sum(np_A, axis=0)

# IMPLEMENTE EM PYTORCH AQUI:
# pt_soma = ...

# %%
# 3. Pegar o índice do maior elemento num vetor (Argmax)
np_vetor = np.array([0.1, 0.8, 0.5, 0.9, 0.2])
np_max_idx = np.argmax(np_vetor)

# IMPLEMENTE EM PYTORCH AQUI:
# pt_max_idx = ...

# %% [markdown]
# ## 🏋️ Desafio Extra
#
# Crie dois tensores de `10.000 x 10.000`. Multiplique-os na CPU e meça o tempo com `time.time()`. Depois (se tiver GPU), mande-os para a GPU e multiplique. Compare o tempo!
