# %% [markdown]
# <div style="background: linear-gradient(135deg, #000 0%, #111 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">Projeto CIFAR-10</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">CNN</p>
# </div>

# %% [markdown]
# ## 🎯 Projeto Final: Construindo uma CNN do Zero para Classificação
#
# ---

# %% [markdown]
# Sua missão é juntar tudo: Dataset, CNN (Camadas, Batchnorm, Dropout), Loss, Otimizador e Loop de Treino.
# Implementaremos um classificador para o dataset FashionMNIST (similar ao MNIST, mas com roupas).

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as T
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

transform = T.Compose([
    T.ToTensor(),
    T.Normalize((0.5,), (0.5,))
])

print('Execute isto no seu Jupyter local para baixar o dataset:')
print("trainset = torchvision.datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)")
print("testset = torchvision.datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)")

# %% [markdown]
# ## 🛠️ Passo 1: Construa a CNN
#
# Defina uma rede com pelo menos 2 Conv2d, seguidas de MaxPool2d e BatchNorm2d. No final, um Flatten e duas Lineares.

# %%
class MinhaCNN(nn.Module):
    def __init__(self):
        super().__init__()
        # SEU CÓDIGO AQUI
        pass

    def forward(self, x):
        # SEU CÓDIGO AQUI
        return x

# %% [markdown]
# ## 🛠️ Passo 2: O Loop de Treino
#
# Instancie otimizador (Adam), Critério (CrossEntropy) e rode por 5 épocas.

# %%
# SEU LOOP DE TREINO AQUI
"""
for epoch in range(5):
    for imagens, labels in trainloader:
        ...
"""

# %% [markdown]
# ## 🛠️ Passo 3: Avaliação
#
# Após treinar, avalie a acurácia no `testloader`. Plote as 5 primeiras imagens que o modelo mais errou (onde `pred != label`)!
