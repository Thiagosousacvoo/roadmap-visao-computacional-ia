# %% [markdown]
# <div style="background: linear-gradient(135deg, #ff006e 0%, #8338ec 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🛠️ 02 — Reverse Process (Adivinhando Ruído)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 10 · Bloco 03 · Difusão</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - O papel da U-Net nos Modelos de Difusão
# - O Processo Reverso de Geração
#
# ---

# %% [markdown]
# ## 1️⃣ O Processo Reverso (Geração)
#
# 1. Começamos com uma imagem composta de 100% de ruído (Estática de TV).
# 2. Passamos o ruído na U-Net e dizemos: 'Estamos no Passo 1000. Qual o ruído que você enxerga?'
# 3. A U-Net cospe um tensor de ruído. Subtraímos uma fração desse ruído da imagem.
# 4. Repetimos o processo até o Passo 0, onde sobrará a imagem limpa e perfeita.

# %%
# Pseudocódigo do Reverse Process (DDPM)
"""
imagem_ruidosa = torch.randn(1, 3, 256, 256) # TV sem sinal

for timestep in reversed(range(1000)):
    # A U-Net precisa saber em que passo está para calcular a escala do ruído!
    ruido_previsto = unet(imagem_ruidosa, timestep)
    
    # Subtrai o ruído (Matemática pesada de probabilidade resumida aqui)
    imagem_ruidosa = remover_fração_de_ruido(imagem_ruidosa, ruido_previsto, timestep)
"""
print('O Midjourney e o DALL-E rodam um loop muito parecido com este a cada geração!')

# %% [markdown]
# ## 2️⃣ Positional Encoding de Tempo
#
# Como a U-Net sabe em qual passo `timestep` ela está? Injetamos a variável `t` nela usando Positional Encoding (O mesmo de Senos e Cossenos que vimos nos Transformers na Fase 06).

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. Modelos como DALL-E e Midjourney recebem Texto ('Um astronauta num cavalo'). Como a U-Net junta a informação da Imagem Ruidosa com o Embedding do Texto (Cross-Attention)?
