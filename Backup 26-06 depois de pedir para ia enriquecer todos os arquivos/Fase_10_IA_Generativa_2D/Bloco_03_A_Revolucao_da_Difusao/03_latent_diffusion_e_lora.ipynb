# %% [markdown]
# <div style="background: linear-gradient(135deg, #ff006e 0%, #8338ec 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🧠 03 — Latent Diffusion e LoRA</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 10 · Bloco 03 · Difusão</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - A Revolução do Latent Diffusion (Stable Diffusion)
# - Como gerar imagens em casa sem um Supercomputador da OpenAI
#
# ---

# %% [markdown]
# ## 1️⃣ O Problema do Pixel Space
#
# Rodar 1000 passos de Denoising numa U-Net processando imagens em 1024x1024 exigiria dezenas de Gigabytes de VRAM. Ninguém rodaria isso em casa.

# %% [markdown]
# ## 2️⃣ Latent Diffusion (Stable Diffusion)
#
# Os autores pegaram um VAE (Sim, aquele do Bloco 01!) e treinaram para comprimir imagens 512x512 num Espaço Latente de 64x64x4.
# Eles rodam TODA a matemática pesada da Difusão de Ruído dentro desse Espaço Latente (Tensor minúsculo).
# Só no final, eles pegam o tensor 64x64, jogam no **Decoder do VAE**, e a imagem limpa 512x512 sai pronta.
# Isso reduziu o custo de GPU em 64 vezes!

# %%
# Pipeline simplificado do Stable Diffusion:
"""
1. text_embeds = clip_text_encoder('foto de gato')
2. latent_noise = torch.randn(1, 4, 64, 64) # Ruido minúsculo
3. for t in passos:
       ruido_pred = unet(latent_noise, t, context=text_embeds)
       latent_noise = latent_noise - ruido_pred
4. img_final_512 = vae_decoder(latent_noise)
"""
print('A IA Generativa moderna é o Frankenstein perfeito: VAE + Transformer (CLIP) + U-Net de Difusão.')

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. O que é o LoRA (Low-Rank Adaptation) e como ele permite treinar o Stable Diffusion para gerar o rosto de uma pessoa específica usando apenas uma Placa de Vídeo caseira de 8GB?
