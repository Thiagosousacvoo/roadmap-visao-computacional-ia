# %% [markdown]
# <div style="background: linear-gradient(135deg, #a8dadc 0%, #457b9d 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🎭 02 — Mask R-CNN (O Nível de Instância)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 08 · Bloco 04 · Refinamento</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - Compreender a Mask R-CNN para Segmentação de Instâncias
# - Como ela usa a Faster R-CNN por baixo
#
# ---

# %% [markdown]
# ## 1️⃣ Além da U-Net
#
# A U-Net não sabe diferenciar o 'Cachorro A' do 'Cachorro B' se eles encostarem.
# A Mask R-CNN usa uma RPN (Region Proposal Network) para achar o Bounding Box de cada cachorro. **Dentro** desse bbox, ela aplica uma pequena FCN (Fully Convolutional Network) que desenha a máscara só para aquele cachorro.

# %%
# Exemplo via Torchvision
"""
import torchvision
model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)
model.eval()

pred = model(images) # Retorna Bboxes, Labels, Scores e MASKS!
"""
print('A Mask R-CNN é ideal para sistemas complexos (ex: contar células individuais em microscopia).')

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. Como você montaria o Dataset (As máscaras) para treinar uma Mask R-CNN? (Dica: o dataset COCO usa polígonos/JSON, não imagens PNG para cada classe).
