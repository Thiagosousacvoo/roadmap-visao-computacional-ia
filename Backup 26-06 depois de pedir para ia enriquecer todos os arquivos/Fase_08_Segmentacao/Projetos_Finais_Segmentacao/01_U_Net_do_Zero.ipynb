# %% [markdown]
# # Novo Notebook

# %% [markdown]
# ## 🎯 Projeto Final: Segmentação de Veículos (U-Net)
#
# ---

# %% [markdown]
# Sua missão é baixar o dataset 'Carvana Image Masking Challenge' (Kaggle) ou qualquer outro dataset de segmentação de um objeto, e treinar uma U-Net do zero para separar o carro do fundo.

# %%
# Estrutura esperada do seu projeto:
"""
1. class CarDataset(Dataset): # Ler imagem e máscara PNG, aplicar os transforms certos
2. class UNet(nn.Module): # Sua arquitetura Encoder-Decoder
3. loss_fn = BCEWithLogitsLoss() + DiceLoss()
4. loop_treino()
5. iou = calcular_iou()
"""

# %% [markdown]
# Mostre os resultados no final exibindo: Imagem Original, Máscara Real e Máscara Predita lado a lado.
