# %% [markdown]
# <div style='background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%); padding: 30px; border-radius: 15px; box-shadow: 0 10px 20px rgba(0,0,0,0.3); color: white; border-left: 5px solid #00f2fe;'>
#     <h1 style='margin:0; font-family: "Segoe UI", sans-serif; font-weight: 800; letter-spacing: 2px; font-size: 2.5em; text-transform: uppercase; text-shadow: 2px 2px 4px rgba(0,0,0,0.5);'>
#         🚀 Trilha de IA: O Guia Definitivo
#     </h1>
#     <p style='margin: 15px 0 0 0; font-family: "Courier New", monospace; font-size: 1.2em; opacity: 0.9; border-top: 1px solid rgba(255,255,255,0.2); padding-top: 10px;'>
#         Do Zero ao Deployment — Construindo o Futuro
#     </p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - A dor de anotar pixels manualmente (CVAT, Roboflow)
# - Usando SAM para acelerar o processo

# %% [markdown]
# ## 1️⃣ O Custo da Segmentação
#
# Fazer Bounding Boxes demora 2 segundos por objeto. Pintar os pixels exatos de um tumor médico demora 5 minutos por objeto. Segmentação é absurdamente cara em termos de tempo humano.

# %%
print('Ferramentas modernas como CVAT permitem que você use uma Inteligência Artificial auxiliar (como o SAM - Segment Anything) para pré-pintar o objeto usando apenas 1 clique humano. Isso corta o tempo em 90%.')

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. No formato COCO, uma máscara de segmentação NÃO é salva como uma imagem PNG preta e branca. Como ela é salva no JSON? (Dica: Polígonos).
