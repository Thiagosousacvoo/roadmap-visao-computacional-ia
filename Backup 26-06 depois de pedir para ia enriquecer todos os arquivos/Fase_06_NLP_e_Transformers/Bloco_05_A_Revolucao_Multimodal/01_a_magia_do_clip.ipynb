# %% [markdown]
# <div style="background: linear-gradient(135deg, #ffd166 0%, #ef476f 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🔗 01 — Unindo Imagem e Texto (CLIP)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 06 · Bloco 05 · CLIP</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - Entender a magia por trás da IA Multimodal
# - O modelo CLIP (Contrastive Language-Image Pre-training)
# - Classificação Zero-Shot
#
# ---

# %% [markdown]
# ## 1️⃣ O que o CLIP faz?
#
# Em vez de classificar `[0,1]` (Gato/Cachorro), a OpenAI treinou um modelo para **aproximar embeddings de Imagem e Texto** num mesmo espaço vetorial.
# A imagem do cachorro gera o vetor `V_img`. A frase 'uma foto de um cachorro' gera o vetor `V_txt`. O objetivo do treino é: Similaridade(V_img, V_txt) chegar a 1.0.

# %%
# Para rodar clip, você precisaria: pip install git+https://github.com/openai/CLIP.git
print('Pseudocódigo de como o CLIP classifica sem nunca ter sido treinado para isso (Zero-Shot):')
"""
1. image_embed = encoder_vit(imagem)
2. text_embed_1 = encoder_text("uma foto de um gato")
3. text_embed_2 = encoder_text("uma foto de um cachorro")
4. similaridade_gato = cosine_sim(image_embed, text_embed_1)
5. similaridade_cao  = cosine_sim(image_embed, text_embed_2)
6. O que der maior probabilidade (Softmax), vence!
"""

# %% [markdown]
# ## 2️⃣ Por que é revolucionário?
#
# Porque você pode mudar as classes (ex: 'Roda de Carro' vs 'Motor de Avião') e classificar perfeitamente SEM TREINAR O MODELO DE NOVO. Ele leu toda a internet, logo sabe o que são esses objetos.

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. Se você tentar criar um gerador de imagem (como Midjourney/Stable Diffusion), como você usaria o modelo CLIP no processo? (Dica: o CLIP diz se a imagem gerada bate com o texto do usuário).
