# %% [markdown]
# <div style="background: linear-gradient(135deg, #00b4d8 0%, #0077b6 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🏋️ 01 — Treinando o Seu Próprio YOLO</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 07 · Bloco 04 · Custom YOLO</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - Como treinar o YOLO num Dataset próprio em poucas linhas
# - Hiperparâmetros vitais
#
# ---

# %% [markdown]
# ## 1️⃣ O Famoso model.train()
#
# Esqueça os loops for complexos do PyTorch (zero_grad, loss.backward). O Ultralytics cuida disso.

# %%
# Código real para treinar:
"""
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # Partimos do Nano, já pré-treinado!

results = model.train(
    data='data.yaml',       # Onde estão os dados e classes
    epochs=100,             # Rodadas
    imgsz=640,              # Tamanho de imagem no treino
    batch=16,               # Imagens por vez na GPU
    device=0,               # GPU(0) ou 'cpu'
    patience=20,            # Early stopping se não melhorar em 20 epocas
    save=True,              # Salvar best.pt
    project='meu_detector', # Pasta para salvar
    name='tentativa_1'
)
"""
print('Fácil, não? O segredo está no Fine-Tuning. O modelo já vem inteligente.')

# %% [markdown]
# ## 2️⃣ Analisando as Métricas pós-treino
#
# Após o treino, você terá uma pasta `runs/detect/tentativa_1/` cheia de gráficos (Loss, PR_curve). A métrica que você procura exibir no seu currículo é a `mAP50-95`.

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. Por que é vital definir a variável `imgsz=640` no treinamento se suas imagens originais são 4K (3840x2160)? O que aconteceria se tentasse treinar na resolução original?
#
# ### Q2. Se você tem 100 imagens no treino, quantas imagens o otimizador processará numa única época usando `batch=16`?
