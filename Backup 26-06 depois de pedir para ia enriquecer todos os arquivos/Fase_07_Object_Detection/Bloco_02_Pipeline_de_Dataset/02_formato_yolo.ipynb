# %% [markdown]
# <div style="background: linear-gradient(135deg, #ff9e00 0%, #ff5400 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🗂️ 02 — Estrutura de Pastas (O data.yaml)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 07 · Bloco 02 · Datasets</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - Estruturar pastas no formato oficial Ultralytics / YOLO
# - Criar o arquivo `data.yaml`
#
# ---

# %% [markdown]
# ## 1️⃣ A Árvore de Diretórios
#
# O YOLO exige que `images` e `labels` tenham os exatos mesmos nomes de arquivo.

# %%
import os

# Como seu projeto deve estar antes de treinar:
arvore = """
meu_dataset/
├── images/
│   ├── train/
│   │   ├── img_01.jpg
│   │   └── img_02.jpg
│   └── val/
│       └── img_03.jpg
├── labels/
│   ├── train/
│   │   ├── img_01.txt
│   │   └── img_02.txt
│   └── val/
│       └── img_03.txt
└── data.yaml
"""
print(arvore)

# %% [markdown]
# ## 2️⃣ O data.yaml
#
# Esse arquivo aponta para as pastas e diz quantas classes existem.

# %%
yaml_fake = """
path: ./meu_dataset
train: images/train
val: images/val

nc: 2
names: ['capacete', 'sem_capacete']
"""
print('Este arquivo será consumido por model.train(data="data.yaml")')

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. O que acontece se o arquivo `img_01.jpg` não tiver um correspondente `img_01.txt` na pasta `labels`? O YOLO ignora a imagem ou considera que ela não tem objetos (Background)?
