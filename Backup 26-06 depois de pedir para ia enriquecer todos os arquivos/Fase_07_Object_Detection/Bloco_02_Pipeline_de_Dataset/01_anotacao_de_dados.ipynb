# %% [markdown]
# <div style="background: linear-gradient(135deg, #ff9e00 0%, #ff5400 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🏷️ 01 — Anotação e Rotulagem</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 07 · Bloco 02 · Datasets</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - O que define um bom Dataset de Detecção
# - Ferramentas: Roboflow e LabelImg
#
# ---

# %% [markdown]
# ## 1️⃣ O Trabalho do Engenheiro
#
# Redes pré-treinadas já estão prontas. O que define se seu projeto vai dar certo é o **Dataset**.
# - Bboxes devem ser apertados (tight) aos limites do objeto.
# - Todas as instâncias da classe na imagem devem ser anotadas. (Esquecer um carro no fundo confunde a rede gerando Falsos Negativos durante o treino).

# %%
"""
Dica de Ouro de Anotação:
- Se o objeto está ocluído (atrás de uma árvore), anote as partes visíveis.
- Use ferramentas como o LabelImg para arquivos offline, ou o Roboflow para equipes.
"""
print('GIGO: Garbage In, Garbage Out.')

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. Por que é importante ter imagens no Dataset *sem nenhum* objeto de interesse (Background images)? O que isso ensina à rede?
