# %% [markdown]
# <div style='background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%); padding: 30px; border-radius: 15px; box-shadow: 0 10px 20px rgba(0,0,0,0.3); color: white; border-left: 5px solid #00f2fe;'>
#     <h1 style='margin:0; font-family: "Segoe UI", sans-serif; font-weight: 800; letter-spacing: 2px; font-size: 2.5em; text-transform: uppercase; text-shadow: 2px 2px 4px rgba(0,0,0,0.5);'>
#         🚀 Trilha de IA: O Guia Definitivo
#     </h1>
#     <p style='margin: 15px 0 0 0; font-family: "Courier New", monospace; font-size: 1.2em; opacity: 0.9; border-top: 1px solid rgba(255,255,255,0.2); padding-top: 10px;'>
#         Do Zero ao Deployment — Construindo o Futuro
#     </p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - Entender o Tensor de Saída de um YOLO `[S, S, B*5 + C]`
# - Non-Maximum Suppression (NMS)

# %% [markdown]
# ## 1️⃣ O Tensor Maluco
#
# O YOLO divide a imagem em um Grid (ex: 7x7). Cada célula do grid prevê Caixas.
# Se 3 caixas diferentes forem geradas para o mesmo cachorro, precisamos de um 'limpador' para apagar os clones.

# %%
print('O Non-Maximum Suppression (NMS) olha para caixas sobrepostas. Ele preserva a caixa com Maior Confiança, e deleta as outras baseando-se no IoU (Intersection over Union).')

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. Se o limite de IoU do NMS for configurado para 0.0, o que acontece com a detecção de duas pessoas caminhando lado a lado?
