# %% [markdown]
# <div style="background: linear-gradient(135deg, #2b9348 0%, #007f5f 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">⚡ 01 — Exportação (Saindo do Python)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 07 · Bloco 06 · Deploy</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - Desapegar dos pesos em `.pt` (PyTorch)
# - Exportar para formatos de alta velocidade: ONNX e TensorRT
#
# ---

# %% [markdown]
# ## 1️⃣ Por que Exportar?
#
# O formato `.pt` do PyTorch é ótimo para treinar. Mas para inferência (deploy) em produção (uma câmera Intel, um drone, uma API), rodar o interpretador Python inteiro é pesado e lento.
# O formato **ONNX** é universal e suportado em C++, C#, JS e mobile.

# %%
# Exportando (requer pacote onnx)
"""
from ultralytics import YOLO

model = YOLO('best.pt')  # Seu modelo treinado

# Exporta para ONNX
path = model.export(format='onnx', opset=11)
print(f'Modelo exportado com sucesso em: {path}')

# Agora você pode rodar a inferência no ONNX via OpenCV (cv2.dnn)
"""

# %% [markdown]
# ## 2️⃣ TensorRT (O Deus da Velocidade da NVIDIA)
#
# Se o deploy for feito numa placa de vídeo da NVIDIA (ex: Jetson Nano, ou servidores na nuvem), você DEVE usar o **TensorRT**. Ele compila e funde camadas da rede e transforma seu YOLO que rodava a 60 FPS em um monstro de 200 FPS!

# %%
# Exporta para Engine (TensorRT)
"""
# Requer GPU nvidia e os pacotes TensorRT instalados via pip (pode ser chatinho no Windows)
model.export(format='engine', device=0)
"""

# %% [markdown]
# ## 3️⃣ Quantização INT8
#
# Sua rede usa números `float32` (alta precisão). Você pode comprimi-la para usar inteiros de 8 bits (`int8`). O modelo cai de 20MB para 5MB, fica 3x mais rápido na CPU, com uma queda quase imperceptível no mAP.

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. Por que um modelo compilado para TensorRT (Engine) numa máquina com RTX 4090 não funcionará se você copiar o arquivo e tentar rodar num servidor com uma placa T4 da AWS?
#
# ### Q2. Pesquise: O que é OpenVINO e para qual hardware ele otimiza as inferências?
