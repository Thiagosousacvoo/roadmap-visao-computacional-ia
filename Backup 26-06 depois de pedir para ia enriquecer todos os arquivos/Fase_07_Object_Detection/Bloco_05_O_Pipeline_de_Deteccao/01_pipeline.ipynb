# %% [markdown]
# <div style='background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%); padding: 30px; border-radius: 15px; box-shadow: 0 10px 20px rgba(0,0,0,0.3); color: white; border-left: 5px solid #00f2fe;'>
#     <h1 style='margin:0; font-family: "Segoe UI", sans-serif; font-weight: 800; letter-spacing: 2px; font-size: 2.5em; text-transform: uppercase; text-shadow: 2px 2px 4px rgba(0,0,0,0.5);'>
#         🚀 Trilha de IA: O Guia Definitivo
#     </h1>
#     <p style='margin: 15px 0 0 0; font-family: "Courier New", monospace; font-size: 1.2em; opacity: 0.9; border-top: 1px solid rgba(255,255,255,0.2); padding-top: 10px;'>
#         Do Zero ao Deployment — Construindo o Futuro
#     </p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - A diferença entre Região Proposta (R-CNN) vs Single Shot (YOLO)
# - O Gargalo da R-CNN original

# %% [markdown]
# ## 1️⃣ Dois Estágios vs Um Estágio
#
# A R-CNN original recortava 2000 pedaços da imagem por fora da rede neural (Selective Search) e passava cada pedaço na CNN separadamente. Era absurdamente lento.

# %%
print('O YOLO resolveu isso tratando a detecção como um problema de REGRESSÃO única. A imagem entra uma vez, e o tensor de saída já contém as coordenadas da caixa e a classe.')

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. Modelos Two-Stage como Faster R-CNN ainda são mais lentos que o YOLO. Em qual cenário industrial você escolheria um Faster R-CNN ao invés de um YOLOv8?
