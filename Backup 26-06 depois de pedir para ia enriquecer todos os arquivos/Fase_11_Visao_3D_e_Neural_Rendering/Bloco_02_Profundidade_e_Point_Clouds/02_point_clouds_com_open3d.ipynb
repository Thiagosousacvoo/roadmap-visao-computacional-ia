# %% [markdown]
# <div style="background: linear-gradient(135deg, #023e8a 0%, #0096c7 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">☁️ 02 — Nuvem de Pontos com Open3D</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 11 · Bloco 02 · Nuvem de Pontos</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - Nuvens de Pontos (Point Clouds)
# - O Padrão Ouro do 3D: Biblioteca Open3D
#
# ---

# %% [markdown]
# ## 1️⃣ Juntando Imagem RGB com Mapa de Profundidade
#
# Se você tem uma foto colorida e o mapa de profundidade, você pode 'desprojetar' (inverter a multiplicação da matriz Intrínseca) os pixels de volta pro mundo 3D.
# O resultado é uma nuvem de milhares de pontos `(X, Y, Z, R, G, B)` flutuando no espaço.

# %%
# Pseudocódigo Open3D
"""
import open3d as o3d

color = o3d.io.read_image('foto.jpg')
depth = o3d.io.read_image('profundidade.png')

rgbd = o3d.geometry.RGBDImage.create_from_color_and_depth(color, depth)
intrinsics = o3d.camera.PinholeCameraIntrinsic(...)

pcd = o3d.geometry.PointCloud.create_from_rgbd_image(rgbd, intrinsics)
o3d.visualization.draw_geometries([pcd])
"""
print('A nuvem de pontos será visível em 3D e você poderá rotacionar a câmera com o mouse.')

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. Um LiDAR gera um Point Cloud naturalmente, mas sem cor. Ao fundir a Nuvem do LiDAR com uma Câmera RGB, qual Matriz precisamos saber milimetricamente para alinhar as duas? (Intrínseca ou Extrínseca?)
