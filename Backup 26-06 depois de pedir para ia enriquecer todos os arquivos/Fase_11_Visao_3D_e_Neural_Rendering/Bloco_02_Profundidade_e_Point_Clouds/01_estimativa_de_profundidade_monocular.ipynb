# %% [markdown]
# <div style="background: linear-gradient(135deg, #023e8a 0%, #0096c7 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🕳️ 01 — DepthAnything (Fingindo Ter Dois Olhos)</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 11 · Bloco 02 · Nuvem de Pontos</p>
# </div>

# %% [markdown]
# ## 🎯 Objetivos
#
# - Monocular Depth Estimation (Adivinhando o 3D com 1 olho só)
# - Modelos baseados em Transformers para Profundidade (MiDaS / DPT)
#
# ---

# %% [markdown]
# ## 1️⃣ O Impossível Feito Possível
#
# Para ter noção de profundidade sem IA, precisamos de Duas Câmeras (Stereo Vision, igual aos nossos olhos).
# Como as CNNs/Transformers conseguem advinhar a profundidade de uma foto 2D?
# **Contexto Semântico:** A rede sabe o tamanho médio de um carro. Se o carro está pequeno na foto, a rede julga que o Z dele é distante.

# %%
# Exemplo via PyTorch Hub (MiDaS)
"""
import torch
import cv2

# Baixa o MiDaS, modelo de ponta mantido pela Intel
midas = torch.hub.load('intel-isl/MiDaS', 'MiDaS_small')
midas.eval()

# O modelo devolve um Mapa de Profundidade (Tons de Cinza)
# Onde branco é 'perto' e preto é 'longe'.
"""
print('O Mapa de Profundidade não dá a distância real em Metros, apenas uma distância RELATIVA.')

# %% [markdown]
# ## 🏋️ Questões
#
# ### Q1. Modelos monocular falham bastante em espelhos e poças d'água. Por quê?
