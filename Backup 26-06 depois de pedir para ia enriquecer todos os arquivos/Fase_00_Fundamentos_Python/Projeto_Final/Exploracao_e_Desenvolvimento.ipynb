# %% [markdown]
# <div style="background: linear-gradient(135deg, #212529 0%, #343a40 100%); padding: 30px; border-radius: 12px; margin-bottom: 20px;">
#   <h1 style="color: white; margin: 0; font-size: 2em;">🔬 Exploração e Desenvolvimento</h1>
#   <p style="color: #d1f2eb; margin: 8px 0 0 0; font-size: 1.1em;">Fase 00 · Projeto Final</p>
# </div>

# %% [markdown]
# ## 🎯 O Sandbox do Projeto
#
# Antes de colocar código nos arquivos `.py` (como `dataset.py`, `processor.py` e rodar no `main.py`), os Cientistas de Dados testam a lógica num notebook "sandbox" como este.
#
# ---

# %% [markdown]
# ## O Problema
#
# Construir um Pipeline ETL orientado a objetos que:
# 1. Lê arquivos CSV.
# 2. Limpa dados faltantes.
# 3. Salva em um novo diretório.
#
# Use este arquivo livremente para rascunhar o Pandas e a lógica das classes.

# %%
import pandas as pd
import numpy as np

print("Sandbox pronto. Importe seus dados e comece os testes!")

# %% [markdown]
# ## 🚀 Missão Especial: Análise de Dados na Prática (Complemento)
#
# Como prometido pelo seu tutor, aqui está um direcionamento para garantir que seu projeto Python seja robusto:

# %% [markdown]
# ### 1️⃣ O Problema do Mundo Real
#
# Encontre um CSV no Kaggle com dados reais (ex: Vendas, Dados Climáticos, ou até informações sobre Datasets de Imagem - como tamanhos, resoluções e classes).
# Não use dados perfeitos. Baixe algo que venha com dados nulos (`NaN`) ou linhas corrompidas.

# %%
# Exemplo do que você deve construir no seu notebook:
import pandas as pd
import matplotlib.pyplot as plt

# 1. Carregue os dados
# df = pd.read_csv('seu_arquivo.csv')

# 2. Limpe os dados (Remova duplicatas, lide com NaNs)
# 3. Crie pelo menos 2 gráficos de insight (Barra e Dispersão)
# plt.show()

print('Este é o núcleo do Python para Cientistas. Codifique a solução nesta seção!')
